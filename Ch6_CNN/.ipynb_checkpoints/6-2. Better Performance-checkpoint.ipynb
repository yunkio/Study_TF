# %% [markdown]
# # 6.4 퍼포먼스 높이기

# %% [markdown]
# ## 6.4.1 더 많은 레이어 쌓기

# %%
import tensorflow as tf

fashion_mnist = tf.keras.datasets.fashion_mnist
(train_X, train_Y), (test_X, test_Y) = fashion_mnist.load_data()

train_X = train_X / 255.0
test_X = test_X / 255.0

train_X = train_X.reshape(-1, 28, 28, 1)
test_X = test_X.reshape(-1, 28, 28, 1)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=32, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, padding='valid', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 256)       295168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               4719104
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 5,240,842
# Trainable params: 5,240,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.random.set_seed(126)

history = model.fit(train_X, train_Y, epochs=25, validation_split=0.25)

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()

model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Epoch 1/25
# 1407/1407 [==============================] - 15s 8ms/step - loss: 0.5918 - accuracy: 0.7821 - val_loss: 0.3326 - val_accuracy: 0.8780
# Epoch 2/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.3705 - accuracy: 0.8687 - val_loss: 0.2859 - val_accuracy: 0.8921
# Epoch 3/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.3290 - accuracy: 0.8812 - val_loss: 0.2556 - val_accuracy: 0.9004
# Epoch 4/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.3067 - accuracy: 0.8895 - val_loss: 0.2495 - val_accuracy: 0.9064
# Epoch 5/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2914 - accuracy: 0.8940 - val_loss: 0.2666 - val_accuracy: 0.8981
# Epoch 6/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2819 - accuracy: 0.8994 - val_loss: 0.2325 - val_accuracy: 0.9123
# Epoch 7/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2700 - accuracy: 0.9033 - val_loss: 0.2313 - val_accuracy: 0.9166
# Epoch 8/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2610 - accuracy: 0.9064 - val_loss: 0.2389 - val_accuracy: 0.9138
# Epoch 9/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2560 - accuracy: 0.9087 - val_loss: 0.2196 - val_accuracy: 0.9209
# Epoch 10/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2607 - accuracy: 0.9073 - val_loss: 0.2229 - val_accuracy: 0.9170
# Epoch 11/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2485 - accuracy: 0.9116 - val_loss: 0.2118 - val_accuracy: 0.9253
# Epoch 12/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2465 - accuracy: 0.9108 - val_loss: 0.2118 - val_accuracy: 0.9227
# Epoch 13/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2418 - accuracy: 0.9126 - val_loss: 0.2185 - val_accuracy: 0.9198
# Epoch 14/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2449 - accuracy: 0.9126 - val_loss: 0.2055 - val_accuracy: 0.9245
# Epoch 15/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2362 - accuracy: 0.9138 - val_loss: 0.2080 - val_accuracy: 0.9267
# Epoch 16/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2413 - accuracy: 0.9135 - val_loss: 0.2080 - val_accuracy: 0.9277
# Epoch 17/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2390 - accuracy: 0.9142 - val_loss: 0.2040 - val_accuracy: 0.9275
# Epoch 18/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2358 - accuracy: 0.9158 - val_loss: 0.2122 - val_accuracy: 0.9241
# Epoch 19/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2334 - accuracy: 0.9174 - val_loss: 0.2057 - val_accuracy: 0.9264
# Epoch 20/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2346 - accuracy: 0.9182 - val_loss: 0.1957 - val_accuracy: 0.9296
# Epoch 21/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2292 - accuracy: 0.9177 - val_loss: 0.2083 - val_accuracy: 0.9259
# Epoch 22/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2309 - accuracy: 0.9181 - val_loss: 0.2184 - val_accuracy: 0.9247
# Epoch 23/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2279 - accuracy: 0.9192 - val_loss: 0.2233 - val_accuracy: 0.9197
# Epoch 24/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2286 - accuracy: 0.9194 - val_loss: 0.2052 - val_accuracy: 0.9276
# Epoch 25/25
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.2307 - accuracy: 0.9182 - val_loss: 0.2051 - val_accuracy: 0.9276
# [0.21912600100040436, 0.9230999946594238]

# %% [markdown]
# ## 6.4.2 이미지 보강

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

tf.random.set_seed(126)

image_generator = ImageDataGenerator(
            rotation_range=10,
            zoom_range=0.10,
            shear_range=0.5,
            width_shift_range=0.10,
            height_shift_range=0.10,
            horizontal_flip=True,
            vertical_flip=False)

augment_size = 100

x_augmented = image_generator.flow(np.tile(train_X[0].reshape(28*28),100).reshape(-1,28,28,1), np.zeros(augment_size), batch_size=augment_size, shuffle=False).next()[0]

# 새롭게 생성된 이미지 표시
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for c in range(100):
    plt.subplot(10,10,c+1)
    plt.axis('off')
    plt.imshow(x_augmented[c].reshape(28,28), cmap='gray')
plt.show()

# %%
tf.random.set_seed(126)

image_generator = ImageDataGenerator(
            rotation_range=10,
            zoom_range=0.10,
            shear_range=0.5,
            width_shift_range=0.10,
            height_shift_range=0.10,
            horizontal_flip=True,
            vertical_flip=False)

augment_size = 30000

randidx = np.random.randint(train_X.shape[0], size=augment_size)
x_augmented = train_X[randidx].copy()
y_augmented = train_Y[randidx].copy()
x_augmented = image_generator.flow(x_augmented, np.zeros(augment_size),
                                   batch_size=augment_size, shuffle=False).next()[0]

# 원래 데이터인 x_train 에 Image Augmentation 된 x_augmented 를 추가합니다.
train_X = np.concatenate((train_X, x_augmented))
train_Y = np.concatenate((train_Y, y_augmented))

print(train_X.shape)
# Out:
# (90000, 28, 28, 1)

# %%
tf.random.set_seed(126)

model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=32, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, padding='valid', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

history = model.fit(train_X, train_Y, epochs=25, validation_split=0.25)

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()

model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Epoch 1/25
# 2110/2110 [==============================] - 16s 7ms/step - loss: 0.5779 - accuracy: 0.7894 - val_loss: 0.5395 - val_accuracy: 0.7898
# Epoch 2/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.3784 - accuracy: 0.8635 - val_loss: 0.4995 - val_accuracy: 0.8048
# Epoch 3/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.3371 - accuracy: 0.8788 - val_loss: 0.4571 - val_accuracy: 0.8235
# Epoch 4/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.3188 - accuracy: 0.8847 - val_loss: 0.4328 - val_accuracy: 0.8383
# Epoch 5/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.3059 - accuracy: 0.8890 - val_loss: 0.4192 - val_accuracy: 0.8413
# Epoch 6/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2964 - accuracy: 0.8931 - val_loss: 0.4215 - val_accuracy: 0.8408
# Epoch 7/25
# 2110/2110 [==============================] - 16s 7ms/step - loss: 0.2899 - accuracy: 0.8956 - val_loss: 0.4107 - val_accuracy: 0.8459
# Epoch 8/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2773 - accuracy: 0.8999 - val_loss: 0.4156 - val_accuracy: 0.8424
# Epoch 9/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2808 - accuracy: 0.9009 - val_loss: 0.3951 - val_accuracy: 0.8555
# Epoch 10/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2714 - accuracy: 0.9020 - val_loss: 0.4188 - val_accuracy: 0.8440
# Epoch 11/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2703 - accuracy: 0.9025 - val_loss: 0.4134 - val_accuracy: 0.8443
# Epoch 12/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2690 - accuracy: 0.9034 - val_loss: 0.4090 - val_accuracy: 0.8532
# Epoch 13/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2698 - accuracy: 0.9046 - val_loss: 0.3783 - val_accuracy: 0.8603
# Epoch 14/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2668 - accuracy: 0.9049 - val_loss: 0.3801 - val_accuracy: 0.8642
# Epoch 15/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2637 - accuracy: 0.9059 - val_loss: 0.3808 - val_accuracy: 0.8626
# Epoch 16/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2602 - accuracy: 0.9077 - val_loss: 0.3776 - val_accuracy: 0.8589
# Epoch 17/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2578 - accuracy: 0.9087 - val_loss: 0.4042 - val_accuracy: 0.8481
# Epoch 18/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2593 - accuracy: 0.9076 - val_loss: 0.3808 - val_accuracy: 0.8586
# Epoch 19/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2562 - accuracy: 0.9090 - val_loss: 0.3786 - val_accuracy: 0.8624
# Epoch 20/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2549 - accuracy: 0.9101 - val_loss: 0.3698 - val_accuracy: 0.8664
# Epoch 21/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2524 - accuracy: 0.9102 - val_loss: 0.3699 - val_accuracy: 0.8650
# Epoch 22/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2518 - accuracy: 0.9105 - val_loss: 0.4157 - val_accuracy: 0.8518
# Epoch 23/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2560 - accuracy: 0.9109 - val_loss: 0.3924 - val_accuracy: 0.8588
# Epoch 24/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2495 - accuracy: 0.9113 - val_loss: 0.3800 - val_accuracy: 0.8624
# Epoch 25/25
# 2110/2110 [==============================] - 15s 7ms/step - loss: 0.2505 - accuracy: 0.9105 - val_loss: 0.3751 - val_accuracy: 0.8626
# [0.2069893777370453, 0.9261999726295471]
