# %% [markdown]
# # 6.2 주요 레이어 정리

# %%
import tensorflow as tf

# %%
conv1 = tf.keras.layers.Conv2D(kernel_size=(3,3),strides=(2,2),padding='valid' ,filters=16)

# %%
pool1 = tf.keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2))

# %% [markdown]
# # 6.3 Fashion MNIST 데이터세트에 적용하기

# %%
# 6.4 Fashion MNIST 데이터셋 불러오기 및 정규화
import tensorflow as tf

fashion_mnist = tf.keras.datasets.fashion_mnist
(train_X, train_Y), (test_X, test_Y) = fashion_mnist.load_data()

train_X = train_X / 255.0
test_X = test_X / 255.0

# %%
print("- reshape 이전")
print(train_X.shape, test_X.shape)

train_X = train_X.reshape(-1, 28, 28, 1)
test_X = test_X.reshape(-1, 28, 28, 1)

print("\n- reshpae 이후")
print(train_X.shape, test_X.shape)
# Out:
# - reshape 이전
# (60000, 28, 28) (10000, 28, 28)
#
# - reshpae 이후
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for c in range(16):
    plt.subplot(4,4,c+1)
    plt.imshow(train_X[c].reshape(28,28), cmap='gray')
    
plt.show()

print(train_Y[:16])
# Out:
# [9 0 0 3 0 2 7 2 5 5 0 9 5 5 7 9]

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=16),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=32),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 16)        160
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 32)        4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 22, 22, 64)        18496
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 3,989,642
# Trainable params: 3,989,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.random.set_seed(126)

history = model.fit(train_X, train_Y, epochs=25, validation_split=0.25)

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()

model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Epoch 1/25
# 1407/1407 [==============================] - 10s 5ms/step - loss: 0.4646 - accuracy: 0.8344 - val_loss: 0.3912 - val_accuracy: 0.8594
# Epoch 2/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.3373 - accuracy: 0.8770 - val_loss: 0.3671 - val_accuracy: 0.8665
# Epoch 3/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2826 - accuracy: 0.8954 - val_loss: 0.3990 - val_accuracy: 0.8645
# Epoch 4/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2440 - accuracy: 0.9091 - val_loss: 0.3951 - val_accuracy: 0.8655
# Epoch 5/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2129 - accuracy: 0.9223 - val_loss: 0.4037 - val_accuracy: 0.8727
# Epoch 6/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1892 - accuracy: 0.9296 - val_loss: 0.4539 - val_accuracy: 0.8633
# Epoch 7/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1662 - accuracy: 0.9373 - val_loss: 0.4812 - val_accuracy: 0.8671
# Epoch 8/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1504 - accuracy: 0.9431 - val_loss: 0.5297 - val_accuracy: 0.8689
# Epoch 9/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1337 - accuracy: 0.9506 - val_loss: 0.5972 - val_accuracy: 0.8653
# Epoch 10/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1284 - accuracy: 0.9530 - val_loss: 0.6779 - val_accuracy: 0.8594
# Epoch 11/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1174 - accuracy: 0.9577 - val_loss: 0.6601 - val_accuracy: 0.8705
# Epoch 12/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1087 - accuracy: 0.9608 - val_loss: 0.6964 - val_accuracy: 0.8649
# Epoch 13/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1001 - accuracy: 0.9630 - val_loss: 0.7360 - val_accuracy: 0.8529
# Epoch 14/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1011 - accuracy: 0.9640 - val_loss: 0.8446 - val_accuracy: 0.8634
# Epoch 15/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0935 - accuracy: 0.9665 - val_loss: 0.7974 - val_accuracy: 0.8576
# Epoch 16/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0860 - accuracy: 0.9688 - val_loss: 0.8581 - val_accuracy: 0.8657
# Epoch 17/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0863 - accuracy: 0.9699 - val_loss: 0.9032 - val_accuracy: 0.8691
# Epoch 18/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0804 - accuracy: 0.9718 - val_loss: 0.9712 - val_accuracy: 0.8589
# Epoch 19/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0725 - accuracy: 0.9739 - val_loss: 1.0105 - val_accuracy: 0.8611
# Epoch 20/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0741 - accuracy: 0.9744 - val_loss: 1.1203 - val_accuracy: 0.8592
# Epoch 21/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0714 - accuracy: 0.9751 - val_loss: 1.1440 - val_accuracy: 0.8596
# Epoch 22/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0658 - accuracy: 0.9781 - val_loss: 1.1299 - val_accuracy: 0.8634
# Epoch 23/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0687 - accuracy: 0.9774 - val_loss: 1.1844 - val_accuracy: 0.8562
# Epoch 24/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0664 - accuracy: 0.9783 - val_loss: 1.2133 - val_accuracy: 0.8615
# Epoch 25/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.0640 - accuracy: 0.9792 - val_loss: 1.2742 - val_accuracy: 0.8583
# [1.2969107627868652, 0.854200005531311]

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=32),
    tf.keras.layers.MaxPool2D(strides=(2,2)),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64),
    tf.keras.layers.MaxPool2D(strides=(2,2)),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               147584
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 241,546
# Trainable params: 241,546
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.random.set_seed(126)

history = model.fit(train_X, train_Y, epochs=25, validation_split=0.25)

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()

model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Epoch 1/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.5218 - accuracy: 0.8111 - val_loss: 0.3617 - val_accuracy: 0.8643
# Epoch 2/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.3587 - accuracy: 0.8692 - val_loss: 0.3352 - val_accuracy: 0.8777
# Epoch 3/25
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.3171 - accuracy: 0.8843 - val_loss: 0.3197 - val_accuracy: 0.8794
# Epoch 4/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2908 - accuracy: 0.8938 - val_loss: 0.3040 - val_accuracy: 0.8856
# Epoch 5/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2664 - accuracy: 0.9008 - val_loss: 0.2939 - val_accuracy: 0.8941
# Epoch 6/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2520 - accuracy: 0.9067 - val_loss: 0.2925 - val_accuracy: 0.8949
# Epoch 7/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2330 - accuracy: 0.9138 - val_loss: 0.3160 - val_accuracy: 0.8937
# Epoch 8/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2232 - accuracy: 0.9160 - val_loss: 0.3138 - val_accuracy: 0.8917
# Epoch 9/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2130 - accuracy: 0.9204 - val_loss: 0.3149 - val_accuracy: 0.8974
# Epoch 10/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2010 - accuracy: 0.9244 - val_loss: 0.3187 - val_accuracy: 0.8973
# Epoch 11/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1961 - accuracy: 0.9271 - val_loss: 0.3159 - val_accuracy: 0.8937
# Epoch 12/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1863 - accuracy: 0.9298 - val_loss: 0.3502 - val_accuracy: 0.8946
# Epoch 13/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1777 - accuracy: 0.9339 - val_loss: 0.3743 - val_accuracy: 0.8949
# Epoch 14/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1697 - accuracy: 0.9376 - val_loss: 0.3310 - val_accuracy: 0.8993
# Epoch 15/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1634 - accuracy: 0.9372 - val_loss: 0.3479 - val_accuracy: 0.8983
# Epoch 16/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1604 - accuracy: 0.9404 - val_loss: 0.3907 - val_accuracy: 0.8960
# Epoch 17/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1599 - accuracy: 0.9418 - val_loss: 0.4078 - val_accuracy: 0.8970
# Epoch 18/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1523 - accuracy: 0.9422 - val_loss: 0.4041 - val_accuracy: 0.8919
# Epoch 19/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1500 - accuracy: 0.9453 - val_loss: 0.4041 - val_accuracy: 0.8977
# Epoch 20/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1444 - accuracy: 0.9462 - val_loss: 0.4196 - val_accuracy: 0.8981
# Epoch 21/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1403 - accuracy: 0.9501 - val_loss: 0.4642 - val_accuracy: 0.8954
# Epoch 22/25
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1361 - accuracy: 0.9484 - val_loss: 0.4555 - val_accuracy: 0.8921
# Epoch 23/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1353 - accuracy: 0.9499 - val_loss: 0.4119 - val_accuracy: 0.8954
# Epoch 24/25
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.1326 - accuracy: 0.9514 - val_loss: 0.5190 - val_accuracy: 0.8957
# Epoch 25/25
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1299 - accuracy: 0.9521 - val_loss: 0.4659 - val_accuracy: 0.8930
# [0.4937308728694916, 0.8863999843597412]
